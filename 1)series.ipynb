# %%
# !pip install pandas

# %%
import numpy as np
import pandas as pd

# %%
labels=['a','b','c']
my_list=[10,23,43]
arr=np.array([10,20,30])
d={'a':10,'b':20,'c':30}

# %%
pd.Series(my_list)
# Out:
# 0    10
# 1    23
# 2    43
# dtype: int64

# %%
pd.Series(my_list ,index=arr)
# Out:
# 10    10
# 20    23
# 30    43
# dtype: int64
