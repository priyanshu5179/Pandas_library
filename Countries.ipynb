# %%
import numpy as np
import pandas as pd

# %%
pd.read.csv("anime.csv")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 pd.read.csv("anime.csv")
#
# AttributeError: module 'pandas' has no attribute 'read'
