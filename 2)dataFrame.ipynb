# %%
import numpy as np
import pandas as pd

# %%
data = {
    'Name': ['John', 'Anna', 'Peter', 'Linda'],
    'Age': [28, 34, 29, 42],
    'City': ['New York', 'Paris', 'Berlin', 'London'],
    'Salary': [65000, 70000, 62000, 85000]
}
df = pd.DataFrame(data)

# %%
df
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
data_list = [
    ['John', 28, 'New York', 65000],
    ['Anna', 34, 'Paris', 70000],
    ['Peter', 29, 'Berlin', 62000],
    ['Linda', 42, 'London', 85000]
]
df2 = pd.DataFrame(data_list)
columns = ["Name","Age","City","Salary"]
df2 = pd.DataFrame(data_list,columns =columns)
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2
# Out:
#     Name  Age      City  Salary
# 0   John   28  New York   65000
# 1   Anna   34     Paris   70000
# 2  Peter   29    Berlin   62000
# 3  Linda   42    London   85000

# %%
df2['degination']=["eng","doct","police","nurs"]

# %%
df2
# Out:
#     Name  Age      City  Salary degination
# 0   John   28  New York   65000        eng
# 1   Anna   34     Paris   70000       doct
# 2  Peter   29    Berlin   62000     police
# 3  Linda   42    London   85000       nurs

# %% [markdown]
# removing columns

# %%
df2.drop('degination' , axis=1, inplace=True)

# %%
df2.drop(0 ,  axis=0)
# Out:
#     Name  Age    City  Salary degination
# 1   Anna   34   Paris   70000       doct
# 2  Peter   29  Berlin   62000     police
# 3  Linda   42  London   85000       nurs

# %%
df2.drop('Name',axis=1)
# Out:
#    Age      City  Salary degination
# 0   28  New York   65000        eng
# 1   34     Paris   70000       doct
# 2   29    Berlin   62000     police
# 3   42    London   85000       nurs

# %% [markdown]
# selecting row

# %%
df2
# Out:
#     Name  Age      City  Salary degination
# 0   John   28  New York   65000        eng
# 1   Anna   34     Paris   70000       doct
# 2  Peter   29    Berlin   62000     police
# 3  Linda   42    London   85000       nurs

# %%
df2.loc[[0,1]]
# Out:
#    Name  Age      City  Salary degination
# 0  John   28  New York   65000        eng
# 1  Anna   34     Paris   70000       doct

# %%
df2.loc[[1]]
# Out:
#    Name  Age   City  Salary degination
# 1  Anna   34  Paris   70000       doct

# %%
df.iloc[2]
# Out:
# Name       Peter
# Age           29
# City      Berlin
# Salary     62000
# Name: 2, dtype: object

# %% [markdown]
# selecting subset of row and column

# %%
df.loc[[0,1]][['Age','City']]
# Out:
#    Age      City
# 0   28  New York
# 1   34     Paris

# %% [markdown]
# conditional statement

# %%
df2
# Out:
#     Name  Age      City  Salary degination
# 0   John   28  New York   65000        eng
# 1   Anna   34     Paris   70000       doct
# 2  Peter   29    Berlin   62000     police
# 3  Linda   42    London   85000       nurs

# %%
df2[df2['Age']<30]
# Out:
#     Name  Age      City  Salary degination
# 0   John   28  New York   65000        eng
# 2  Peter   29    Berlin   62000     police

# %%
##I only want to see those people whose age is above 30

# %%
df2[df2['Age']>30]
# Out:
#     Name  Age    City  Salary degination
# 1   Anna   34   Paris   70000       doct
# 3  Linda   42  London   85000       nurs

# %%
#I only want poeple whose age is above 30 and their city must be paris

# %%
df2[(df2["Age"]>30)&(df2["City"]=='Paris')]
# Out:
#    Name  Age   City  Salary degination
# 1  Anna   34  Paris   70000       doct

# %%
df2
# Out:
#     Name  Age      City  Salary degination
# 0   John   28  New York   65000        eng
# 1   Anna   34     Paris   70000       doct
# 2  Peter   29    Berlin   62000     police
# 3  Linda   42    London   85000       nurs
